# %% [markdown]
# <a href="https://colab.research.google.com/github/vikranthrach/IIT-Patna--AI-and-ML-Course/blob/main/B2_Sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3
import seaborn as sns

# Create database
conn = sqlite3.connect('joins_practice.db')

# Create sample tables
students = pd.DataFrame({
    'student_id': [1, 2, 3, 4, 5],
    'name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
    'class_id': [101, 102, 101, None, 103]
})

classes = pd.DataFrame({
    'class_id': [101, 102, 104],
    'class_name': ['Math', 'Science', 'History'],
    'teacher': ['Mr. Smith', 'Ms. Johnson', 'Mr. Brown']
})

grades = pd.DataFrame({
    'student_id': [1, 2, 3, 6],
    'subject': ['Math', 'Science', 'Math', 'English'],
    'grade': ['A', 'B', 'A', 'C']
})

# Save to database
students.to_sql('students', conn, if_exists='replace', index=False)
classes.to_sql('classes', conn, if_exists='replace', index=False)
grades.to_sql('grades', conn, if_exists='replace', index=False)

print("Sample tables created!")
print(f"Students: {len(students)} rows")
print(f"Classes: {len(classes)} rows")
print(f"Grades: {len(grades)} rows")

conn.close()
# Out:
# Sample tables created!
# Students: 5 rows
# Classes: 3 rows
# Grades: 4 rows

# %%
students
# Out:
#    student_id     name  class_id
# 0           1    Alice     101.0
# 1           2      Bob     102.0
# 2           3  Charlie     101.0
# 3           4    Diana       NaN
# 4           5      Eve     103.0

# %%
classes
# Out:
#    class_id class_name      teacher
# 0       101       Math    Mr. Smith
# 1       102    Science  Ms. Johnson
# 2       104    History    Mr. Brown

# %%
grades
# Out:
#    student_id  subject grade
# 0           1     Math     A
# 1           2  Science     B
# 2           3     Math     A
# 3           6  English     C

# %%
print(101.0==101)
# Out:
# True

# %%
inner_join = '''SELECT * FROM students INNER JOIN classes ON
students.class_id = classes.class_id'''

conn = sqlite3.connect('joins_practice.db')

df_sql = pd.read_sql(inner_join, conn)
df_sql
# Out:
#    student_id     name  class_id  class_id class_name      teacher
# 0           1    Alice     101.0       101       Math    Mr. Smith
# 1           2      Bob     102.0       102    Science  Ms. Johnson
# 2           3  Charlie     101.0       101       Math    Mr. Smith

# %%
inner_join = '''SELECT students.student_id,
 students.name,
 students.class_id,
 class_name, teacher
 FROM students INNER JOIN classes ON
students.class_id = classes.class_id'''

conn = sqlite3.connect('joins_practice.db')

df_sql = pd.read_sql(inner_join, conn)
df_sql
# Out:
#    student_id     name  class_id class_name      teacher
# 0           1    Alice     101.0       Math    Mr. Smith
# 1           2      Bob     102.0    Science  Ms. Johnson
# 2           3  Charlie     101.0       Math    Mr. Smith

# %%
inner_join = '''SELECT
 s.student_id,
 s.name,
 s.class_id,
 c.class_name,
 c.teacher
 FROM students as s INNER JOIN classes as c ON
 s.class_id = c.class_id'''

conn = sqlite3.connect('joins_practice.db')

df_sql = pd.read_sql(inner_join, conn)
df_sql
# Out:
#    student_id     name  class_id class_name      teacher
# 0           1    Alice     101.0       Math    Mr. Smith
# 1           2      Bob     102.0    Science  Ms. Johnson
# 2           3  Charlie     101.0       Math    Mr. Smith

# %%
result = pd.merge(students, classes,
                  on = 'class_id',
                  how='inner')
result
# Out:
#    student_id     name  class_id class_name      teacher
# 0           1    Alice     101.0       Math    Mr. Smith
# 1           2      Bob     102.0    Science  Ms. Johnson
# 2           3  Charlie     101.0       Math    Mr. Smith

# %%
inner_join = '''SELECT
 s.student_id,
 s.name,
 s.class_id,
 c.class_name,
 c.teacher
 FROM classes as c INNER JOIN students as s ON
 s.class_id = c.class_id'''

conn = sqlite3.connect('joins_practice.db')

df_sql = pd.read_sql(inner_join, conn)
df_sql
# Out:
#    student_id     name  class_id class_name      teacher
# 0           1    Alice     101.0       Math    Mr. Smith
# 1           3  Charlie     101.0       Math    Mr. Smith
# 2           2      Bob     102.0    Science  Ms. Johnson

# %%
grades
# Out:
#    student_id  subject grade
# 0           1     Math     A
# 1           2  Science     B
# 2           3     Math     A
# 3           6  English     C

# %%
inner_join = '''SELECT
 s.student_id,
 s.name,
 s.class_id,
 c.class_name,
 c.teacher,
 g.subject,
 g.grade
 FROM classes as c INNER JOIN students as s ON
 s.class_id = c.class_id
 INNER JOIN grades as g ON s.student_id = g.student_id
 '''

conn = sqlite3.connect('joins_practice.db')

df_sql = pd.read_sql(inner_join, conn)
df_sql
# Out:
#    student_id     name  class_id class_name      teacher  subject grade
# 0           1    Alice     101.0       Math    Mr. Smith     Math     A
# 1           3  Charlie     101.0       Math    Mr. Smith     Math     A
# 2           2      Bob     102.0    Science  Ms. Johnson  Science     B

# %%
df_sql.to_excel("temp.xlsx")

# %%
left_query = '''SELECT
    *
FROM students
LEFT JOIN classes
ON students.class_id = classes.class_id;'''


df_sql = pd.read_sql(left_query, conn)
df_sql
# Out:
#    student_id     name  class_id  class_id class_name      teacher
# 0           1    Alice     101.0     101.0       Math    Mr. Smith
# 1           2      Bob     102.0     102.0    Science  Ms. Johnson
# 2           3  Charlie     101.0     101.0       Math    Mr. Smith
# 3           4    Diana       NaN       NaN       None         None
# 4           5      Eve     103.0       NaN       None         None

# %%
left_query = '''SELECT
    *
FROM classes
LEFT JOIN students
ON students.class_id = classes.class_id;'''


df_sql = pd.read_sql(left_query, conn)
df_sql
# Out:
#    class_id class_name      teacher  student_id     name  class_id
# 0       101       Math    Mr. Smith         1.0    Alice     101.0
# 1       101       Math    Mr. Smith         3.0  Charlie     101.0
# 2       102    Science  Ms. Johnson         2.0      Bob     102.0
# 3       104    History    Mr. Brown         NaN     None       NaN

# %%
left_query = '''SELECT
    *
FROM classes
LEFT JOIN students
ON students.class_id = classes.class_id;'''


df_sql = pd.read_sql(left_query, conn)
df_sql
# Out:
#    class_id class_name      teacher  student_id     name  class_id
# 0       101       Math    Mr. Smith         1.0    Alice     101.0
# 1       101       Math    Mr. Smith         3.0  Charlie     101.0
# 2       102    Science  Ms. Johnson         2.0      Bob     102.0
# 3       104    History    Mr. Brown         NaN     None       NaN

# %%
left_query = '''SELECT
    *
FROM classes
RIGHT JOIN students
ON students.class_id = classes.class_id;'''


df_sql = pd.read_sql(left_query, conn)
df_sql
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: RIGHT and FULL OUTER JOINs are not currently supported
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_9895/3491958900.py in <cell line: 0>()
#       6
#       7
# ----> 8 df_sql = pd.read_sql(left_query, conn)
#       9 df_sql
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704     with pandasSQL_builder(con) as pandas_sql:
# ...

# %%
result = pd.merge(
    students,
    classes,
    on='class_id',
    how='right'
)
result
# Out:
#    student_id     name  class_id class_name      teacher
# 0         1.0    Alice     101.0       Math    Mr. Smith
# 1         3.0  Charlie     101.0       Math    Mr. Smith
# 2         2.0      Bob     102.0    Science  Ms. Johnson
# 3         NaN      NaN     104.0    History    Mr. Brown

# %%
pd.merge(result, table3, on = "", how = "")

# %%
result = pd.merge(
    classes,
    students,
    on='class_id',
    how='left'
)
result
# Out:
#    class_id class_name      teacher  student_id     name
# 0       101       Math    Mr. Smith         1.0    Alice
# 1       101       Math    Mr. Smith         3.0  Charlie
# 2       102    Science  Ms. Johnson         2.0      Bob
# 3       104    History    Mr. Brown         NaN      NaN

# %%
result = pd.merge(
    students,
    classes,
    on='class_id',
    how='left'
)
result
# Out:
#    student_id     name  class_id class_name      teacher
# 0           1    Alice     101.0       Math    Mr. Smith
# 1           2      Bob     102.0    Science  Ms. Johnson
# 2           3  Charlie     101.0       Math    Mr. Smith
# 3           4    Diana       NaN        NaN          NaN
# 4           5      Eve     103.0        NaN          NaN

# %% [markdown]
# # Download the db from this git -
# https://github.com/lerocha/chinook-database/tree/master

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import sqlite3
import pandas as pd

# Connect to the Chinook database
conn = sqlite3.connect('chinook.db')

# Quick check — list all tables
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", conn)
print("Tables in Chinook:")
print(tables)
# Out:
# Tables in Chinook:
#              name
# 0           Album
# 1          Artist
# 2        Customer
# 3        Employee
# 4           Genre
# 5         Invoice
# 6     InvoiceLine
# 7       MediaType
# 8        Playlist
# 9   PlaylistTrack
# 10          Track

# %%
# Load tables we'll use for joins
artists = pd.read_sql("SELECT * FROM Artist", conn)
albums = pd.read_sql("SELECT * FROM Album", conn)
tracks = pd.read_sql("SELECT * FROM Track", conn)
genres = pd.read_sql("SELECT * FROM Genre", conn)
customers = pd.read_sql("SELECT * FROM Customer", conn)
invoices = pd.read_sql("SELECT * FROM Invoice", conn)
invoice_lines = pd.read_sql("SELECT * FROM InvoiceLine", conn)
employee = pd.read_sql("SELECT * FROM Employee", conn)

print(f"Artists: {len(artists)} rows")
print(f"Albums: {len(albums)} rows")
print(f"Tracks: {len(tracks)} rows")
print(f"Genres: {len(genres)} rows")
print(f"Customers: {len(customers)} rows")
print(f"Invoices: {len(invoices)} rows")
print(f"InvoiceLines: {len(invoice_lines)} rows")
# Out:
# Artists: 275 rows
# Albums: 347 rows
# Tracks: 3503 rows
# Genres: 25 rows
# Customers: 59 rows
# Invoices: 412 rows
# InvoiceLines: 2240 rows

# %%
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %%
tracks
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %%
artists
# Out:
#      ArtistId                                               Name
# 0           1                                              AC/DC
# 1           2                                             Accept
# 2           3                                          Aerosmith
# 3           4                                  Alanis Morissette
# 4           5                                    Alice In Chains
# ..        ...                                                ...
# 270       271   Mela Tenenbaum, Pro Musica Prague & Richard Kapp
# 271       272                             Emerson String Quartet
# 272       273  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 273       274                                      Nash Ensemble
# 274       275                              Philip Glass Ensemble
#
# [275 rows x 2 columns]

# %%
albums
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %%
    name
0           Album
1          Artist
2        Customer
3        Employee
4           Genre
5         Invoice
6     InvoiceLine
7       MediaType
8        Playlist
9   PlaylistTrack
10          Track

# %%
sql = ''' select * from Artist INNER JOIN Album on Artist.ArtistId = Album.ArtistId'''
tables2 = pd.read_sql(sql, conn)
tables2
# Out:
#      ArtistId                                               Name  AlbumId  \
# 0           1                                              AC/DC        1
# 1           2                                             Accept        2
# 2           2                                             Accept        3
# 3           1                                              AC/DC        4
# 4           3                                          Aerosmith        5
# ..        ...                                                ...      ...
# 342       226                                     Eugene Ormandy      343
# 343       272                             Emerson String Quartet      344
# 344       273  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...      345
# 345       274                                      Nash Ensemble      346
# 346       275                              Philip Glass Ensemble      347
#
#                                                  Title  ArtistId
# ...

# %%
pd.merge(artists, albums, on= 'ArtistId', how='inner')
# Out:
#      ArtistId                                               Name  AlbumId  \
# 0           1                                              AC/DC        1
# 1           1                                              AC/DC        4
# 2           2                                             Accept        2
# 3           2                                             Accept        3
# 4           3                                          Aerosmith        5
# ..        ...                                                ...      ...
# 342       271   Mela Tenenbaum, Pro Musica Prague & Richard Kapp      342
# 343       272                             Emerson String Quartet      344
# 344       273  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...      345
# 345       274                                      Nash Ensemble      346
# 346       275                              Philip Glass Ensemble      347
#
#                                                  Title
# ...

# %%
pd.merge(tracks,
          genres,
          on = 'GenreId',
          how = 'inner',
          suffixes = ("_track", "_genre"))
# Out:
#       TrackId                                         Name_track  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %%
tracks.columns
# Out:
# Index(['TrackId', 'Name', 'AlbumId', 'MediaTypeId', 'GenreId', 'Composer',
#        'Milliseconds', 'Bytes', 'UnitPrice'],
#       dtype='object')

# %%
df2 = pd.merge(tracks, albums, on = "AlbumId", how = 'inner',
          suffixes = ("_tracks", "_albums"))
df2
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %%
pd.merge(df2, genres, on = 'GenreId', how="inner",  suffixes = ("_df2", "_genre"))
# Out:
#       TrackId                                           Name_df2  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %%
full_catalog = (
    tracks
    .merge(albums, on='AlbumId')
    .merge(artists, on='ArtistId')
    .merge(genres, on='GenreId', suffixes=('_artist', '_genre'))
)
full_catalog
# Out:
#       TrackId                                             Name_x  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %% [markdown]
# # Which artists have no albums

# %%
query = '''select Artist.ArtistId, Artist.Name from
        Artist Left Join Album on Artist.ArtistId = Album.ArtistId
        where Album.AlbumId is NULL'''

df3 = pd.read_sql(query, conn)
df3
# Out:
#     ArtistId                                               Name
# 0         25                         Milton Nascimento & Bebeto
# 1         26                                            Azymuth
# 2         28                                      João Gilberto
# 3         29                                     Bebel Gilberto
# 4         30                                      Jorge Vercilo
# ..       ...                                                ...
# 66       192                 DJ Dolores & Orchestra Santa Massa
# 67       193                                          Seu Jorge
# 68       194                               Sabotage E Instituto
# 69       195                                    Stereo Maracana
# 70       239  Academy of St. Martin in the Fields, Sir Nevil...
#
# [71 rows x 2 columns]

# %%
artists_albums = pd.merge(artists, albums, on='ArtistId', how='left')

# Find artists with no albums (NaN in AlbumId)
no_albums = artists_albums[artists_albums['AlbumId'].isna()]
no_albums
# Out:
#      ArtistId                                               Name  AlbumId  \
# 50         25                         Milton Nascimento & Bebeto      NaN
# 51         26                                            Azymuth      NaN
# 55         28                                      João Gilberto      NaN
# 56         29                                     Bebel Gilberto      NaN
# 57         30                                      Jorge Vercilo      NaN
# ..        ...                                                ...      ...
# 327       192                 DJ Dolores & Orchestra Santa Massa      NaN
# 328       193                                          Seu Jorge      NaN
# 329       194                               Sabotage E Instituto      NaN
# 330       195                                    Stereo Maracana      NaN
# 377       239  Academy of St. Martin in the Fields, Sir Nevil...      NaN
#
#     Title
# 50    NaN
# 51    NaN
# 55    NaN
# 56    NaN
# 57    NaN
# ...

# %% [markdown]
# # Which tracks are never purchased at all

# %%
invoice_lines
# Out:
#       InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity
# 0                 1          1        2       0.99         1
# 1                 2          1        4       0.99         1
# 2                 3          2        6       0.99         1
# 3                 4          2        8       0.99         1
# 4                 5          2       10       0.99         1
# ...             ...        ...      ...        ...       ...
# 2235           2236        411     3136       0.99         1
# 2236           2237        411     3145       0.99         1
# 2237           2238        411     3154       0.99         1
# 2238           2239        411     3163       0.99         1
# 2239           2240        412     3177       1.99         1
#
# [2240 rows x 5 columns]

# %%
track_sales = pd.merge(invoice_lines, tracks, on = "TrackId",
         how = "right")
track_sales[track_sales['InvoiceLineId'].isna()]['TrackId']
# Out:
# 7          7
# 13        11
# 19        17
# 20        18
# 25        22
#         ...
# 3751    3497
# 3752    3498
# 3756    3501
# 3757    3502
# 3758    3503
# Name: TrackId, Length: 1519, dtype: int64

# %%
invoices
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2021-01-01 00:00:00
# 1            2           4  2021-01-02 00:00:00
# 2            3           8  2021-01-03 00:00:00
# 3            4          14  2021-01-06 00:00:00
# 4            5          23  2021-01-11 00:00:00
# ..         ...         ...                  ...
# 407        408          25  2025-12-05 00:00:00
# 408        409          29  2025-12-06 00:00:00
# 409        410          35  2025-12-09 00:00:00
# 410        411          44  2025-12-14 00:00:00
# 411        412          58  2025-12-22 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart         None
# 1                            Ullevålsveien 14        Oslo         None
# 2                             Grétrystraat 63    Brussels         None
# 3                              8210 111 ST NW    Edmonton           AB
# ...

# %% [markdown]
# # which emploees have no customers assigend at all ( i need to print employee ful name)

# %%
employee
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %%
employee = employee.rename(columns = {"SupportRepID" : "SupportRepId"})
employee
# Out:
#    SupportRepId  LastName FirstName                Title  ReportsTo  \
# 0             1     Adams    Andrew      General Manager        NaN
# 1             2   Edwards     Nancy        Sales Manager        1.0
# 2             3   Peacock      Jane  Sales Support Agent        2.0
# 3             4      Park  Margaret  Sales Support Agent        2.0
# 4             5   Johnson     Steve  Sales Support Agent        2.0
# 5             6  Mitchell   Michael           IT Manager        1.0
# 6             7      King    Robert             IT Staff        6.0
# 7             8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# ...

# %%
employee.columns
# Out:
# Index(['SupportRepId', 'LastName', 'FirstName', 'Title', 'ReportsTo',
#        'BirthDate', 'HireDate', 'Address', 'City', 'State', 'Country',
#        'PostalCode', 'Phone', 'Fax', 'Email'],
#       dtype='object')

# %%
customers.columns
# Out:
# Index(['CustomerId', 'FirstName', 'LastName', 'Company', 'Address', 'City',
#        'State', 'Country', 'PostalCode', 'Phone', 'Fax', 'Email',
#        'SupportRepId'],
#       dtype='object')

# %%
df5 = pd.merge(employee, customers, on = 'SupportRepId', how = 'left')

df5[df5['CustomerId'].isna()][["FirstName_x", 'LastName_x']]
# Out:
#    FirstName_x LastName_x
# 0       Andrew      Adams
# 1        Nancy    Edwards
# 61     Michael   Mitchell
# 62      Robert       King
# 63       Laura   Callahan

# %%
df5[['FirstName_x', 'LastName_x']]['SupportRepId'].isna()

# %%
# Out:
# Empty DataFrame
# Columns: [SupportRepId, LastName_x, FirstName_x, Title, ReportsTo, BirthDate, HireDate, Address_x, City_x, State_x, Country_x, PostalCode_x, Phone_x, Fax_x, Email_x, CustomerId, FirstName_y, LastName_y, Company, Address_y, City_y, State_y, Country_y, PostalCode_y, Phone_y, Fax_y, Email_y]
# Index: []
#
# [0 rows x 27 columns]

# %%
query = '''
select e.FirstName || ' ' || e.LastName as Employee
from Employee as e Left JOIN Customer as c on
e.EmployeeId = c.SupportRepID
where c.SupportRepID is NULL;
'''
df4 = pd.read_sql(query, conn)
df4
# Out:
#            Employee
# 0      Andrew Adams
# 1     Nancy Edwards
# 2  Michael Mitchell
# 3       Robert King
# 4    Laura Callahan

# %%
customers
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
