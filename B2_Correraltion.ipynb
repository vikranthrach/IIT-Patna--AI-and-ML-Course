# %% [markdown]
# <a href="https://colab.research.google.com/github/vikranthrach/IIT-Patna--AI-and-ML-Course/blob/main/B2_Correraltion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Iris dataset
iris = sns.load_dataset('iris')

# Quick look
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
corr_petal = iris['petal_length'].corr(iris['petal_width'])
corr_petal
# Out:
# np.float64(0.9628654314027961)

# %%
corr_sepal_petal = iris['sepal_length'].corr(iris['petal_length'])
corr_sepal_petal
# Out:
# np.float64(0.8717537758865831)

# %%
corr_weak = iris['sepal_width'].corr(iris['petal_length'])
corr_weak
# Out:
# np.float64(-0.4284401043305394)

# %%
# Calculate correlation matrix
correlation_matrix = iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].corr()

print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(correlation_matrix, annot = True)
# Out:
# <Axes: >

# %%
sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm', linewidth = 1)
# Out:
# <Axes: >

# %%
import numpy as np

np.triu("M")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5531/704895284.py in <cell line: 0>()
#       1 import numpy as np
#       2
# ----> 3 np.triu("M")
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_twodim_base_impl.py in triu(m, k)
#     527     """
#     528     m = asanyarray(m)
# --> 529     mask = tri(*m.shape[-2:], k=k-1, dtype=bool)
#     530
#     531     return where(mask, zeros(1, m.dtype), m)
#
# TypeError: tri() missing 1 required positional argument: 'N'
